# %%
import pandas as pd
import numpy as np

df = pd.read_csv("anime.csv")

# %%
df
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df = pd.read_csv("anime.csv")

# %%
df.head(5)
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Score'], dtype='str')

# %%
df.info
# Out:
# <bound method DataFrame.info of     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df.columns.tolist()
# Out:
# ['Rank', 'Title', 'Score']

# %%
df.head(10)
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5     6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6     7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7     8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8     9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9    10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03

# %%
## 1. Make a new column for Episode Count

# %%
df["Episode Count"] =
df["Title"].str.extract(r'\((\d+) eps\)')
df["Episode Count"] = 
pd.to_numeric(df["Episode Count"])

# %%
df.head()
# Out:
#    Rank                                              Title  Score  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
#
#    Episode Count
# 0             64
# 1             24
# 2             13
# 3             51
# 4             10

# %%
## 2. Make a new column for time stamp

# %%
df.loc[3]['Title']
# Out:
# 'Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 members'

# %%
## 3. Which anime has the highest score

# %%
df.loc[df["Score"].idxmax()]
# Out:
# Rank                                                             1
# Title            Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...
# Score                                                          9.1
# Episode Count                                                   64
# Name: 0, dtype: object

# %%
df.loc[df["Score"].idxmax(), "Title"]
# Out:
# 'Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview'

# %%
## 4. Give me top 5 highest scoring anime

# %%
df.sort_values(by="Score", ascending=False).head(5)
# Out:
#    Rank                                              Title  Score  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
#
#    Episode Count
# 0             64
# 1             24
# 2             13
# 3             51
# 4             10

# %%
df.sort_values(by="Score", ascending=False)[["Title", "Score"]].head(5)
# Out:
#                                                Title  Score
# 0  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
## 5.Which anime has the highest episode count

# %%
df.loc[df["Episode Count"].idxmax()]
# Out:
# Rank                                                            16
# Title            GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...
# Score                                                         8.94
# Episode Count                                                  201
# Name: 15, dtype: object

# %%
df.loc[df["Episode Count"].idxmax(), "Title"]
# Out:
# 'GintamaTV (201 eps)Apr 2006 - Mar 20101,034,418 members'

# %%
## 6. Animes with top 5 episode count

# %%
df.sort_values(by="Episode Count", ascending=False).head(5)
# Out:
#     Rank                                              Title  Score  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 42    43  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...   8.76
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...   8.87
#
#     Episode Count
# 15            201
# 7             148
# 11            110
# 42             75
# 24             74

# %%
df.sort_values(by="Episode Count", ascending=False)[["Title", "Episode Count"]].head(5)
# Out:
#                                                 Title  Episode Count
# 15  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...            201
# 7   Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...            148
# 11  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...            110
# 42  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...             75
# 24  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...             74

# %%
## 7. Which is the longest running anime

# %%
df.loc[df["Episode Count"].idxmax(), ["Title", "Episode Count"]]
# Out:
# Title            GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...
# Episode Count                                                  201
# Name: 15, dtype: object
